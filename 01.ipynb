# %% [markdown]
# # Übung 1

# %% [markdown]
# Hallo liebe Studis. Ihr habt erfolgreich das Repo geclont, klasse. Jetzt gibt es ein paar Aufgaben zum Warmwerden.

# %% [markdown]
# ## Aufgabe 1 Bild-I/O

# %% [markdown]
# Es gibt mehrere python libraries um Bilder einzulesen und darzustellen. Ich empfehle scikit-image. Führe die nächste Zelle aus und installiere ggf. fehlende Bibliotheken wie scikit-image.

# %%
#%matplotlib inline 
from skimage import io, data, color
import numpy as np

image = io.imread('../images/lena.png')

io.imshow(image)

# %% [markdown]
# Es gibt übrigens in skimage.data viele Testbilder, die ihr für Eure Aufgaben nehmen könnt. Führe die nächsten beiden Zellen aus.

# %%
io.imshow(data.coffee())

# %%
    io.imshow(data.astronaut())

# %% [markdown]
# Füge in die nächste Zelle eine Codezeile ein, um für das Lenabild den Bildausschnitt 240 <= x <= 360 und 250 <= y <= 290 darzustellen!

# %% [markdown]
# Konvertiere jetzt das Farbbild in ein Grauwertbild und zeige dieses an!

# %% [markdown]
# Ok. Jetzt benutze scipy's Funktion convolve (in ndimage) um das Grauwertbild zu glätten.

# %%
from scipy import ndimage

# %% [markdown]
# Jetzt wende den Sobeloperator für die x-Ableitung auf das Grauwertbild an.

# %% [markdown]
# Ok, sieht schon ganz gut aus. Jetzt berechne das Magnitudenbild (Summe der Absolutbeträge der Filterantworten) und addiere es auf das Grauwertbild.

# %% [markdown]
# Letzte Aufgabe. Erstelle drei verschiedene Gaußkernel, mit steigender Varianz und Kernel-Größe. Filtere das Lenabild mit diesen Kerneln und zeige die Ergebnisse in einem 100 x 100 Pixel großen Ausschnitt der die Hutfedern enthält.
